# %%
# !git clone https://github.com/fizyr/keras-retinanet
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 6205 (delta 1), reused 3 (delta 1), pack-reused 6196
# Receiving objects: 100% (6205/6205), 14.88 MiB | 35.76 MiB/s, done.
# Resolving deltas: 100% (4191/4191), done.

# %%
# %cd /content/keras-retinanet
# Out:
# /content/keras-retinanet

# %%
# !pip install . --user
# Out:
# Processing /content/keras-retinanet
# ...
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp36-cp36m-linux_x86_64.whl size=168072 sha256=4dc949ea9dd019c3d1b7b971de055233850af5b8fe33e08f5815478e0dfbcc8a
#   Stored in directory: /root/.cache/pip/wheels/b2/9f/57/cb0305f6f5a41fc3c11ad67b8cedfbe9127775b563337827ba
# ...
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20487 sha256=85edfebf976e2b8de40ede44af1c583f7f08abe49237977f2fd9c2a5b6cc1041
#   Stored in directory: /root/.cache/pip/wheels/5f/09/a5/497a30fd9ad9964e98a1254d1e164bcd1b8a5eda36197ecb3c
# Successfully built keras-retinanet keras-resnet
# ...
#   WARNING: The scripts retinanet-convert-model, retinanet-debug, retinanet-evaluate and retinanet-train are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
  # !cp -r /root/.local/bin /usr/local

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/keras-retinanet/keras_retinanet/utils/compute_overlap.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'keras_retinanet.utils.compute_overlap' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/keras_retinanet
# creating build/temp.linux-x86_64-3.6/keras_retinanet/utils
# ...

# %%
# %mkdir dataset

# %%
cd dataset
# Out:
# /content/drive/My Drive/keras-retinanet/dataset

# %%
# !unzip data.zip; rm data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/Dipto_713.jpg
#   inflating: images/Dipto_714.jpg
#   inflating: images/Dipto_715.jpg
#   inflating: images/Dipto_716.jpg
#   inflating: images/Dipto_717.jpg
#   inflating: images/Dipto_718.jpg
#   inflating: images/Dipto_719.jpg
#   inflating: images/Dipto_720.jpg
#   inflating: images/Dipto_721.jpg
#   inflating: images/Dipto_722.jpg
#   inflating: images/Dipto_723.jpg
#   inflating: images/Dipto_724.jpg
#   inflating: images/Dipto_725.jpg
#   inflating: images/Dipto_726.jpg
#   inflating: images/Dipto_727.jpg
#   inflating: images/Dipto_728.jpg
#   inflating: images/Dipto_729.jpg
#   inflating: images/Dipto_730.jpg
#   inflating: images/Dipto_731.jpg
#   inflating: images/Dipto_732.jpg
#   inflating: images/Dipto_733.jpg
#   inflating: images/Dipto_734.jpg
#   inflating: images/Dipto_735.jpg
#   inflating: images/Dipto_736.jpg
#   inflating: images/Dipto_737.jpg
#   inflating: images/Dipto_738.jpg
# ...

# %%
# %mkdir images;

# %mkdir annotations;

# %%
# !pip install unrar

# %%
cd /content/drive/My Drive/keras-retinanet/dataset/submission_test_images
# Out:
# /content/drive/My Drive/keras-retinanet/dataset/submission_test_images

# %%
get_ipython().system_raw("unrar x test1.rar")

# %%
cd /content/drive/My Drive/keras-retinanet/dataset
# Out:
# /content/drive/My Drive/keras-retinanet/dataset

# %%
# %mkdir config
# %mkdir tensorboard
# %mkdir models

# %%
# !pip install requests-html
# Out:
# ...
#      |████████████████████████████████| 153kB 5.6MB/s
# ...
#      |████████████████████████████████| 81kB 4.1MB/s
# ...
#      |████████████████████████████████| 71kB 4.8MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=ccdbc2ce2559ea09209c01dac1f0cab20449abc9205a77b7c63885ee32ca8242
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# ...
#   Created wheel for parse: filename=parse-1.18.0-cp36-none-any.whl size=24133 sha256=f4eceb8c4d1b907f9c101e0ddf75897bea8b1fe35fe5fde2a52418321b021c55
#   Stored in directory: /root/.cache/pip/wheels/2a/53/09/869ca5781ede342254ffac09ca99461b008c3e5f8dd079b0c0
# Successfully built fake-useragent parse
# ERROR: pyppeteer 0.2.2 has requirement urllib3<2.0.0,>=1.25.8, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
# !python build_dataset.py -s 0.9
# Out:
# [INFO] creating 'train' set...
# [INFO] 2702 total images in 'train' set
# [INFO] creating 'test' set...
# [INFO] 301 total images in 'test' set
# [INFO] writing classes...

# %%
# %cat classes.csv
# Out:
# taxi,0
# garbagevan,1
# three wheelers (CNG),2
# bicycle,3
# pickup,4
# rickshaw,5
# suv,6
# army vehicle,7
# van,8
# policecar,9
# truck,10
# minivan,11
# human hauler,12
# scooter,13
# auto rickshaw,14
# wheelbarrow,15
# bus,16
# car,17
# ambulance,18
# minibus,19
# motorbike,20

# %%
# !git clone https://github.com/martinzlocha/anchor-optimization.git
# Out:
# Cloning into 'anchor-optimization'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 77 (delta 39), reused 49 (delta 21), pack-reused 0
# Unpacking objects: 100% (77/77), done.

# %%
cd /content/drive/My Drive/keras-retinanet/
# Out:
# /content/drive/My Drive/keras-retinanet

# %%
pip install .
# Out:
# Processing /content/drive/My Drive/keras-retinanet/anchor-optimization
# ...
#      |████████████████████████████████| 61kB 3.3MB/s
# ...
#   Created wheel for anchor-optimization: filename=anchor_optimization-0.0.1-cp36-cp36m-linux_x86_64.whl size=81399 sha256=1e1ac386353d29e77bc0f53a0b471f9187e22cf5079f6e57f7c052db0cda7981
#   Stored in directory: /root/.cache/pip/wheels/1d/fa/14/a90a399dc1fc02f5c17b58991c0be16082230e5e3c4f717891
# ...
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.5.1-cp36-cp36m-linux_x86_64.whl size=154832 sha256=91067673736ae7a8426ab7a8794f8bbdc806a5f4d0b8f0981aa90d3131d25dc4
#   Stored in directory: /root/.cache/pip/wheels/d9/a5/98/87f8ed08913b184bb625dde1c1277a4dfe969c77b377abde69
# ...
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20487 sha256=e1138bb8a502db118cd3104a816537be40d4b44295531eb4799bb0fadd58d702
#   Stored in directory: /root/.cache/pip/wheels/5f/09/a5/497a30fd9ad9964e98a1254d1e164bcd1b8a5eda36197ecb3c
# ...

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning anchor_optimization/utils/compute_overlap.pyx to anchor_optimization/utils/compute_overlap.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/My Drive/keras-retinanet/anchor-optimization/anchor_optimization/utils/compute_overlap.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'anchor_optimization.utils.compute_overlap' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/anchor_optimization
# creating build/temp.linux-x86_64-3.6/anchor_optimization/utils
# ...

# %%
# !anchor-optimization  dataset/train.csv --ratios=5 --no-resize  --verbose
# Out:
# 2020-11-03 17:24:24.007003: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading object dimensions.
# Optimising anchors.
# Current best anchor configuration
# State: 0.05759
# Ratios: [0.282, 0.332, 1.0, 3.014, 3.549]
# Scales: [0.945, 1.322, 1.728]
# Number of labels that don't have any matching anchor: 1259
#
# Current best anchor configuration
# State: 0.04472
# Ratios: [0.276, 0.827, 1.0, 1.209, 3.624]
# Scales: [0.805, 1.279, 1.314]
# Number of labels that don't have any matching anchor: 896
#
# Current best anchor configuration
# State: 0.02751
# Ratios: [0.258, 0.354, 1.0, 2.824, 3.873]
# Scales: [0.472, 1.259, 1.975]
# Number of labels that don't have any matching anchor: 89
#
# Current best anchor configuration
# State: 0.01915
# Ratios: [0.545, 0.736, 1.0, 1.358, 1.834]
# Scales: [0.433, 1.105, 1.577]
# Number of labels that don't have any matching anchor: 325
#
# Current best anchor configuration
# ...

# %%
 cd ../
# Out:
# /

# %%
# !pip install keras-resnet
# Out:
# ...
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20487 sha256=1c31e4035ade2789f7b506f967e10693767112b2beb6ef7121fd27f8cfdb4466
#   Stored in directory: /root/.cache/pip/wheels/5f/09/a5/497a30fd9ad9964e98a1254d1e164bcd1b8a5eda36197ecb3c
# Successfully built keras-resnet
# ...

# %%
# !python keras_retinanet/bin/train.py --weights snapshots/resnet50_csv_01.h5 \
--batch-size 8  --steps 2758 --epochs 20 \
--freeze-backbone \
--config config/config.ini \
--snapshot-path snapshots \
--tensorboard-dir tensorboard \
--compute-val-loss \
csv dataset/train.csv dataset/classes.csv \
--val-annotations dataset/test.csv
# Out:
# 2020-11-04 13:33:52.366517: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "keras_retinanet/bin/train.py", line 553, in <module>
#     main()
#   File "keras_retinanet/bin/train.py", line 469, in main
#     backbone = models.backbone(args.backbone)
#   File "keras_retinanet/bin/../../keras_retinanet/models/__init__.py", line 57, in backbone
#     from .resnet import ResNetBackbone as b
#   File "keras_retinanet/bin/../../keras_retinanet/models/resnet.py", line 18, in <module>
#     import keras_resnet
# ModuleNotFoundError: No module named 'keras_resnet'

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.3.0
